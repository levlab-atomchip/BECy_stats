# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['axes.labelsize'] = 22
plt.rcParams['axes.titlesize'] = 26
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['lines.linewidth'] = 3

# %%
import sys
sys.path.append(r'C:\Users\LevLab\Documents\GitHub\BECy_stats')
import cloud_distribution as cd
import cloud_image as ci
reload(cd)
reload(ci)
CD = cd.CD
CI = ci.CloudImage

# %%
datadir = r'Z:\Data\ACM Data\Imaging system\PIXIS_darkcount\2015-01-16\fast_adc'

# %%
dist = CD(datadir, False)
img = CI(dist.filelist[0])
plt.imshow(img.dark_image_trunc)
plt.colorbar()
# Out:
# Z:\Data\ACM Data\Imaging system\PIXIS_darkcount\2015-01-16\fast_adc
# <matplotlib.colorbar.Colorbar instance at 0x0B4E41C0>

# %%
light_img = img.light_image_trunc
dark_img = img.dark_image_trunc
atom_img = img.atom_image_trunc
diff = np.int32(light_img)-np.int32(dark_img)

# %%
plt.hist(np.ravel(diff)/0.37)
np.std(np.ravel(diff))
# Out:
# 14.367674287672729

# %%
print img.get_image_time()
print img_hm.get_image_time()
# Out:
# 0.0001
# 0.0001
