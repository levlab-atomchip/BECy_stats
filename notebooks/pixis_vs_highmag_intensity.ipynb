# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['axes.labelsize'] = 22
plt.rcParams['axes.titlesize'] = 26
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['lines.linewidth'] = 3

# %%
import sys
sys.path.append(r'C:\Users\LevLab\Documents\GitHub\BECy_stats')
import cloud_distribution as cd
import cloud_image as ci
reload(cd)
reload(ci)
CD = cd.CD
CI = ci.CloudImage

# %%
datadir = r'Z:\Data\ACM Data\Imaging system\saturation\2015-01-16\highmag_vs_pixis\pixis'

# %%
dist = CD(datadir, False)
img = CI(dist.filelist[0])
plt.imshow(img.get_od_image())
plt.colorbar()
# Out:
# Z:\Data\ACM Data\Imaging system\saturation\2015-01-16\highmag_vs_pixis\pixis
# <matplotlib.colorbar.Colorbar instance at 0x0ECF8418>

# %%
light_counts = np.int32(img.light_image_trunc) - np.int32(img.dark_image_trunc)
plt.imshow(light_counts)
pixis_counts = np.mean(light_counts)

# %%
datadir_hm = r'Z:\Data\ACM Data\Imaging system\saturation\2015-01-16\highmag_vs_pixis\highmag'

# %%
dist_hm = CD(datadir_hm, False)
img_hm = CI(dist_hm.filelist[0])
plt.imshow(img_hm.get_od_image(trunc_switch=False), vmax=2)
plt.colorbar()
# Out:
# Z:\Data\ACM Data\Imaging system\saturation\2015-01-16\highmag_vs_pixis\highmag
# <matplotlib.colorbar.Colorbar instance at 0x0EFEFEE0>

# %%
img_hm.truncate_image(600, 1000, 80, 280)
plt.imshow(img_hm.get_od_image())

# %%
light_counts_hm = np.int32(img_hm.light_image_trunc) - np.int32(img_hm.dark_image_trunc)
plt.imshow(light_counts_hm)
hm_counts = np.mean(light_counts_hm)

# %%
print pixis_counts / 0.95
print hm_counts / 16 / 0.2
# Out:
# 5924.81293239
# 2990.6010625

# %%
plt.hist(np.ravel(light_counts_hm) / 16 / 0.2)
plt.hist(np.ravel(light_counts) / 0.95)
# Out:
# (array([   86,     1,  2664, 13328, 10602, 15834, 12315,  4903,   687,    76]),
#  array([     0.        ,   1151.47368421,   2302.94736842,   3454.42105263,
#           4605.89473684,   5757.36842105,   6908.84210526,   8060.31578947,
#           9211.78947368,  10363.26315789,  11514.73684211]),
#  <a list of 10 Patch objects>)

# %%
print img.get_image_time()
print img_hm.get_image_time()
# Out:
# 0.0001
# 0.0001
