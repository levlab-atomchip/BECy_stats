# %% [raw]
# The goal of this notebook is to fix a problem with field reconstruction whereby we can't seem to get positive fields.

# %% [raw]
# e.g. see 2015-01-06 100 usec field data

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['axes.labelsize'] = 22
plt.rcParams['axes.titlesize'] = 26
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['lines.linewidth'] = 3

# %%
import sys
sys.path.append(r'/home/will/levlab/BECy_stats/')
import cloud_distribution as cd
import cloud_image as ci
reload(cd)
reload(ci)
CD = cd.CD
CI = ci.CloudImage

# %%
datadir = r'/home/will/levlab/data/bfieldnoise_20150106/100us/'

# %%
dist = CD(datadir, False)
# Out:
# /home/will/levlab/data/bfieldnoise_20150106/100us/

# %%
img = CI(dist.filelist[0])

# %%
img.truncate_image(393, 623, 158, 176)
ic_od = img.get_cd_image()*img.s_lambda
plt.imshow(ic_od)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f0bbabdd3b0>

# %%
plt.plot(img.get_gerbier_field()*1e9)

# %% [raw]
# Clearly something is going wrong at the sides of this.

# %%
plt.plot(np.sum(ic_od, axis=0))

# %%
import BECphysics as bp

# %%
ld = bp.line_density(ic_od / img.s_lambda, pixel_size=img.pixel_size)

# %%
plt.plot(ld)

# %%
fa = bp.field_array(ld)
plt.plot(fa*1e9)

# %% [raw]
# problem is definitely creeping in when column density is negative. Which is reasonable, because negative cd is impossible.

# %% [raw]
# One way we often fix this is including more columns in the image for fitting.

# %%
img.truncate_image(300, 700, 158, 176)
ld = bp.line_density(img.get_cd_image(), pixel_size=img.pixel_size)
fa = bp.field_array(ld)
plt.plot(fa*1e9)

# %%
plt.plot(np.sum(img.get_od_image(), axis=0))

# %% [raw]
# Looks as though the gaussian fit is screwing this up. A couple options: find a better way to fit, or scrap the offset correction. I think the latter is fine until proven otherwise because fluctuations are so low with the PIXIS.
