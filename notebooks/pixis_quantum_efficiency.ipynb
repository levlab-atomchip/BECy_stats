# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['axes.labelsize'] = 22
plt.rcParams['axes.titlesize'] = 26
plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
plt.rcParams['lines.linewidth'] = 3

# %%
import sys
sys.path.append(r'C:\Users\LevLab\Documents\GitHub\BECy_stats')
import cloud_distribution as cd
import cloud_image as ci
reload(cd)
reload(ci)
CD = cd.CD
CI = ci.CloudImage

# %%
datadir = r'Z:\Data\ACM Data\Imaging system\quantum_efficiency\2015-01-19\ACM_pixis_10us_VVA10'

# %%
dist = CD(datadir, False)
img = CI(dist.filelist[0])
plt.imshow(img.atom_image)
plt.colorbar()
# Out:
# Z:\Data\ACM Data\Imaging system\quantum_efficiency\2015-01-19\ACM_pixis_10us_VVA10
# <matplotlib.colorbar.Colorbar instance at 0x15894760>

# %%
img.truncate_image(410, 580, 30, 160)
plt.imshow(img.atom_image_trunc)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x15F382B0>

# %%
counts = np.sum(np.int32(img.light_image_trunc) - np.int32(img.dark_image_trunc))
# Out:
# 75137109

# %%
from math import pi
true_power = 5.1e-6
photon_energy = 1.589 * 1.602e-19 #transition energy in eV, from Steck, times electron charge
beam_energy = counts * photon_energy
beam_power = beam_energy / 10e-6
print beam_power

qe = beam_power / true_power
print qe
# Out:
# 1.91267371654e-06
# 0.375034062067

# %%
datadir_varyt = r'Z:\Data\ACM Data\Imaging system\quantum_efficiency\2015-01-19\pixis_vary_t'

# %%
dist_varyt = CD(datadir_varyt, False)
results = []
for fname in dist_varyt.filelist:
    img = CI(fname)
    img.truncate_image(410, 550, 30, 125)
    counts = np.sum(np.int32(img.light_image_trunc) - np.int32(img.dark_image_trunc))
    results.append((img.get_image_time(), counts))
times, cts = zip(*results)
plt.plot(np.array(times)*1e6, cts, marker='o', linestyle='')
cts_per_us = float(min(cts)) / float(min(times)*1e6)
print cts_per_us
tt = np.linspace(0, 50)
plt.plot(tt, cts_per_us*tt)
# Out:
# Z:\Data\ACM Data\Imaging system\quantum_efficiency\2015-01-19\pixis_vary_t
# 785117.1
